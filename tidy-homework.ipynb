# %%
import pandas as pd

# %%
df = pd.read_csv("census.csv")
df.head()
# Out:
#       state  state fips        commodity  \
# 0  US TOTAL          99  FARM OPERATIONS
# 1  US TOTAL          99  FARM OPERATIONS
# 2  US TOTAL          99  FARM OPERATIONS
# 3  US TOTAL          99  FARM OPERATIONS
# 4  US TOTAL          99  FARM OPERATIONS
#
#                                 data item  \
# 0  FARM OPERATIONS - NUMBER OF OPERATIONS
# 1  FARM OPERATIONS - NUMBER OF OPERATIONS
# 2  FARM OPERATIONS - NUMBER OF OPERATIONS
# 3  FARM OPERATIONS - NUMBER OF OPERATIONS
# 4  FARM OPERATIONS - NUMBER OF OPERATIONS
#
#                        domain category       2017       2012       2007  \
# 0                                  NaN  2,042,220  2,109,303  2,204,792
# 1    AREA OPERATED: (1.0 TO 9.9 ACRES)    273,325    223,634    232,849
# 2  AREA OPERATED: (10.0 TO 49.9 ACRES)    583,001    589,549    620,283
# 3     AREA OPERATED: (50 TO 179 ACRES)    564,763    634,047    660,530
# 4    AREA OPERATED: (180 TO 499 ACRES)    315,017    346,038    368,368
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            129 non-null    object
#  1   state fips       129 non-null    int64
#  2   commodity        129 non-null    object
#  3   data item        129 non-null    object
#  4   domain category  15 non-null     object
#  5   2017             127 non-null    object
#  6   2012             124 non-null    object
#  7   2007             124 non-null    object
#  8   2002             124 non-null    object
#  9   1997             117 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 10.2+ KB

# %%
df.isna().any()
# Out:
# state              False
# state fips         False
# commodity          False
# data item          False
# domain category     True
# 2017                True
# 2012                True
# 2007                True
# 2002                True
# 1997                True
# dtype: bool

# %%
dropped_missing = df.dropna()

# %%
df
# Out:
#         state  state fips        commodity  \
# 0    US TOTAL          99  FARM OPERATIONS
# 1    US TOTAL          99  FARM OPERATIONS
# 2    US TOTAL          99  FARM OPERATIONS
# 3    US TOTAL          99  FARM OPERATIONS
# 4    US TOTAL          99  FARM OPERATIONS
# ..        ...         ...              ...
# 124  US TOTAL          99         POTATOES
# 125  US TOTAL          99   SWEET POTATOES
# 126  US TOTAL          99   SWEET POTATOES
# 127  US TOTAL          99         ORCHARDS
# 128  US TOTAL          99         ORCHARDS
#
#                                              data item  \
# 0               FARM OPERATIONS - NUMBER OF OPERATIONS
# 1               FARM OPERATIONS - NUMBER OF OPERATIONS
# 2               FARM OPERATIONS - NUMBER OF OPERATIONS
# 3               FARM OPERATIONS - NUMBER OF OPERATIONS
# 4               FARM OPERATIONS - NUMBER OF OPERATIONS
# ..                                                 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            129 non-null    object
#  1   state fips       129 non-null    int64
#  2   commodity        129 non-null    object
#  3   data item        129 non-null    object
#  4   domain category  15 non-null     object
#  5   2017             127 non-null    object
#  6   2012             124 non-null    object
#  7   2007             124 non-null    object
#  8   2002             124 non-null    object
#  9   1997             117 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 10.2+ KB

# %%
melted_df = df.melt(id_vars = ["state", "state fips", "commodity", "data item", "domain category"],
                   var_name = "year", 
                   value_name = "us total")
melted_df
# Out:
#         state  state fips        commodity  \
# 0    US TOTAL          99  FARM OPERATIONS
# 1    US TOTAL          99  FARM OPERATIONS
# 2    US TOTAL          99  FARM OPERATIONS
# 3    US TOTAL          99  FARM OPERATIONS
# 4    US TOTAL          99  FARM OPERATIONS
# ..        ...         ...              ...
# 640  US TOTAL          99         POTATOES
# 641  US TOTAL          99   SWEET POTATOES
# 642  US TOTAL          99   SWEET POTATOES
# 643  US TOTAL          99         ORCHARDS
# 644  US TOTAL          99         ORCHARDS
#
#                                              data item  \
# 0               FARM OPERATIONS - NUMBER OF OPERATIONS
# 1               FARM OPERATIONS - NUMBER OF OPERATIONS
# 2               FARM OPERATIONS - NUMBER OF OPERATIONS
# 3               FARM OPERATIONS - NUMBER OF OPERATIONS
# 4               FARM OPERATIONS - NUMBER OF OPERATIONS
# ..                                                 ...
# ...

# %%
melted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            645 non-null    object
#  1   state fips       645 non-null    int64
#  2   commodity        645 non-null    object
#  3   data item        645 non-null    object
#  4   domain category  75 non-null     object
#  5   year             645 non-null    object
#  6   us total         616 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 35.4+ KB
